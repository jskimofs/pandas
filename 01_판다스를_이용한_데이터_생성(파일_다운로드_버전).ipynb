# %% [markdown]
# <a href="https://colab.research.google.com/github/jskimofs/pandas/blob/main/01_%ED%8C%90%EB%8B%A4%EC%8A%A4%EB%A5%BC_%EC%9D%B4%EC%9A%A9%ED%95%9C_%EB%8D%B0%EC%9D%B4%ED%84%B0_%EC%83%9D%EC%84%B1(%ED%8C%8C%EC%9D%BC_%EB%8B%A4%EC%9A%B4%EB%A1%9C%EB%93%9C_%EB%B2%84%EC%A0%84).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 이용할 데이터셋:
#
#
# 국립박물관문화재단_박물관상품 기본정보(https://www.data.go.kr/data/15010663/fileData.do)

# %%
#파일을 불러오기 위해 drive 불러오기

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd #판다스를 pd라는 별칭으로 불러오기

# %%
#data 객체에 데이터프레임 할당

data=pd.read_csv('/content/drive/MyDrive/데이터/국립박물관문화재단_박물관상품 기본정보_20231231.csv', encoding='cp949')  #csv 함수로

# %%
#상위 5개 데이터 확인

data.head()
# Out:
#     연번                   상품명   소분류              재질       사이즈(mm)       비고
# 0  1.0      (중앙)어린이박물관 체험꾸러미  문구사무  종이, 플라스틱, 비닐 등  200*185*80mm  국립중앙박물관
# 1  2.0    (중앙)반가캐릭터 방향제_Pink  생활소품        함침물형, 종이         3*6cm  국립중앙박물관
# 2  3.0  (중앙)반가캐릭터 방향제_Yellow  생활소품        함침물형, 종이         3*6cm  국립중앙박물관
# 3  4.0    (중앙)반가캐릭터 방향제_Mint  생활소품        함침물형, 종이         3*6cm  국립중앙박물관
# 4  5.0    (중앙)반가캐릭터 방향제_Blue  생활소품        함침물형, 종이         3*6cm  국립중앙박물관
